# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
        df = pd.read_csv('/home/mishraka/Documents/Manjula/Lambda_School/Housing_data_for_analysis/New_construction_US_census_data.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-19-146c1b88565b> in <module>()
# ----> 1 df = pd.read_csv('/home/mishraka/Documents/Manjula/Lambda_School/Housing_data_for_analysis/New_construction_US_census_data.csv')
#
# ...

# %%
 df = pd.read_csv('/home/mishraka/Documents/Manjula/Lambda_School/harvard_dataests/20_modeling_tables/w-8.csv')

# %%
df.head(20)
# Out:
#    Table W-8.  Metropolitan Trends and Projections for Home Improvement Spending: 2015–2017  \
# 0                                                 NaN
# 1                                   Metropolitan Area
# 2                                                 NaN
# 3                                         Atlanta, GA
# 4                                          Austin, TX
# 5                                       Baltimore, MD
# 6                                      Birmingham, AL
# 7                                          Boston, MA
# 8                                         Buffalo, NY
# 9                                       Charlotte, NC
# 10                                        Chicago, IL
# 11                                     Cincinnati, OH
# 12                                      Cleveland, OH
# 13                                       Columbus, OH
# 14                              Dallas-Fort Worth, TX
# 15                                         Denver, CO
# ...

# %%
df.shape
# Out:
# (61, 9)

# %%
df
# Out:
#    Table W-8.  Metropolitan Trends and Projections for Home Improvement Spending: 2015–2017  \
# 0                                                 NaN
# 1                                   Metropolitan Area
# 2                                                 NaN
# 3                                         Atlanta, GA
# 4                                          Austin, TX
# 5                                       Baltimore, MD
# 6                                      Birmingham, AL
# 7                                          Boston, MA
# 8                                         Buffalo, NY
# 9                                       Charlotte, NC
# 10                                        Chicago, IL
# 11                                     Cincinnati, OH
# 12                                      Cleveland, OH
# 13                                       Columbus, OH
# 14                              Dallas-Fort Worth, TX
# 15                                         Denver, CO
# ...

# %%
df_atlas = pd.read_csv('/home/mishraka/Documents/Manjula/Lambda_School/The_Opportunity_Atlas/cty_covariates.csv')

# %%
df_atlas.head(15)
# Out:
#     county  state       cz      czname  hhinc_mean2000  mean_commutetime2000  \
# 0        1      1  11101.0  Montgomery       74699.969             28.490602
# 1        3      1  11001.0      Mobile       76064.086             26.501080
# 2        5      1  10301.0     Eufaula       51246.004             24.047514
# 3        7      1  10801.0  Tuscaloosa       55094.492             32.875317
# 4        9      1  10700.0  Birmingham       62749.727             36.189240
# 5       11      1   9800.0      Auburn       41518.551             26.251190
# 6       13      1  11101.0  Montgomery       53386.293             26.863214
# 7       15      1   9600.0    LaGrange       60064.410             24.250038
# 8       17      1   9600.0    LaGrange       54240.402             23.371609
# 9       19      1   6600.0        Rome       54810.438             30.194675
# 10      21      1  10700.0  Birmingham       58160.180             34.786503
# ...

# %%
df_atlas.shape
# Out:
# (3223, 35)
