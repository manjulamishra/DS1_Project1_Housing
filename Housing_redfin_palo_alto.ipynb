# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
house = pd.read_csv('/home/mishraka/Documents/Manjula/Lambda_School/Housing_data_for_analysis/Redfin_Palo_Alto.csv')

# %%
# !pwd
# Out:
# /home/mishraka/Documents/Manjula

# %%
house.head(50)
# Out:
#       SALE TYPE  SOLD DATE              PROPERTY TYPE                 ADDRESS  \
# 0   MLS Listing        NaN  Single Family Residential          1251 Bryant St
# 1   MLS Listing        NaN  Single Family Residential        289 Fernando Ave
# 2   MLS Listing        NaN  Single Family Residential         1025 Harker Ave
# 3   MLS Listing        NaN                Condo/Co-op      440 Cesano Ct #311
# 4   MLS Listing        NaN  Single Family Residential         2149 Bowdoin St
# 5   MLS Listing        NaN  Single Family Residential          345 Wilton Ave
# 6   MLS Listing        NaN  Single Family Residential         631 Harvard Ave
# 7   MLS Listing        NaN  Single Family Residential          2991 Alexis Dr
# 8   MLS Listing        NaN                Condo/Co-op  765 San Antonio Rd #37
# 9   MLS Listing        NaN  Single Family Residential        302 Channing Ave
# 10  MLS Listing        NaN  Single Family Residential         3414 Kenneth Dr
# ...

# %%
house.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY', 'STATE',
#        'ZIP', 'PRICE', 'BEDS', 'BATHS', 'LOCATION', 'SQUARE FEET', 'LOT SIZE',
#        'YEAR BUILT', 'DAYS ON MARKET', '$/SQUARE FEET', 'HOA/MONTH', 'STATUS',
#        'NEXT OPEN HOUSE START TIME', 'NEXT OPEN HOUSE END TIME',
#        'URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)',
#        'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
house.shape
# Out:
# (54, 27)

# %%
df =house[['PRICE', 'ZIP', 'BEDS', 'BATHS', 'LOT SIZE','$/SQUARE FEET']]

# %%
df.head(55)
# Out:
#        PRICE    ZIP  BEDS  BATHS  LOT SIZE  $/SQUARE FEET
# 0    3995000  94301   6.0    5.0      8800         1292.0
# 1    2300000  94306   2.0    1.0      6600         2130.0
# 2    4395000  94301   7.0    4.0      9391         1375.0
# 3    1125000  94306   2.0    1.0      1584         1020.0
# 4    2000000  94306   3.0    1.5      4625         1533.0
# 5    2088000  94306   3.0    1.0      6783         1677.0
# 6    2998000  94025   4.0    3.5      9448         1131.0
# 7    3999991  94304   4.0    2.5     47511         1204.0
# 8    1400000  94303   2.0    2.0      1144         1359.0
# 9    3198000  94301   3.0    2.5      2748         1795.0
# 10   2795000  94303   4.0    2.0      7000         1871.0
# 11   2395000  94303   4.0    2.0      7476         1484.0
# 12   2098000  94306   4.0    2.0      6000         1402.0
# 13   1985000  94306   3.0    1.0      6305         1981.0
# 14   4988000  94303   6.0    5.5     13072         1226.0
# ...

# %%
df.isna().sum()
# Out:
# PRICE            0
# ZIP              0
# BEDS             2
# BATHS            7
# LOT SIZE         0
# $/SQUARE FEET    3
# dtype: int64

# %%
print(df)
# Out:
# None

# %%
df.fillna(df.mean())
# Out:
#        PRICE    ZIP  BEDS     BATHS  LOT SIZE  $/SQUARE FEET
# 0    3995000  94301  6.00  5.000000      8800    1292.000000
# 1    2300000  94306  2.00  1.000000      6600    2130.000000
# 2    4395000  94301  7.00  4.000000      9391    1375.000000
# 3    1125000  94306  2.00  1.000000      1584    1020.000000
# 4    2000000  94306  3.00  1.500000      4625    1533.000000
# 5    2088000  94306  3.00  1.000000      6783    1677.000000
# 6    2998000  94025  4.00  3.500000      9448    1131.000000
# 7    3999991  94304  4.00  2.500000     47511    1204.000000
# 8    1400000  94303  2.00  2.000000      1144    1359.000000
# 9    3198000  94301  3.00  2.500000      2748    1795.000000
# 10   2795000  94303  4.00  2.000000      7000    1871.000000
# 11   2395000  94303  4.00  2.000000      7476    1484.000000
# 12   2098000  94306  4.00  2.000000      6000    1402.000000
# 13   1985000  94306  3.00  1.000000      6305    1981.000000
# ...

# %%
df.columns
# Out:
# Index(['PRICE', 'ZIP', 'BEDS', 'BATHS', 'LOT SIZE', '$/SQUARE FEET'], dtype='object')

# %%
plt.plot(df['ZIP']) 
plt.plot(df['PRICE'])
#plt.plot(three_occupations[''])

# %%
df1 = table =pd.crosstab(df.ZIP, df.PRICE, normalize ='index')

# %%
df1
# Out:
# PRICE  1125000   1250000   1400000   1500000   1548000   1750000   1985000   \
# ZIP
# 94025      0.00  0.000000     0.000      0.00      0.00      0.00      0.00
# 94028      0.00  0.000000     0.000      0.00      0.00      0.00      0.00
# 94301      0.00  0.052632     0.000      0.00      0.00      0.00      0.00
# 94303      0.00  0.000000     0.125      0.00      0.00      0.00      0.00
# 94304      0.00  0.000000     0.000      0.00      0.00      0.00      0.00
# 94306      0.05  0.000000     0.000      0.05      0.05      0.05      0.05
#
# PRICE  1988000   1998000   2000000     ...     6888000   6980000   6988000   \
# ZIP                                    ...
# 94025  0.000000      0.00      0.00    ...     0.000000  0.000000  0.000000
# 94028  0.000000      0.00      0.00    ...     0.000000  0.000000  0.000000
# 94301  0.052632      0.00      0.00    ...     0.052632  0.052632  0.052632
# 94303  0.000000      0.00      0.00    ...     0.000000  0.000000  0.000000
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.cm
# cd basemap -1.x.x
# python setup.py install
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.colors import Normalize

# %%
(-122.20266+ (-122.070976))/2
# Out:
# -122.136818

# %%
(38.0682+36.7352)/2
# Out:
# 37.4017

# %%
fig, ax = plt.subplots(figsize=(10,20))

m = Basemap(resolution='c', # c, l, i, h, f or None
            projection='merc',
            lat_0=37.4017, lon_0=-121.5,
            llcrnrlon=-122, llcrnrlat= 36.7352, urcrnrlon=-121, urcrnrlat=38.0682)

m.drawmapboundary(fill_color='#46bcec')
m.drawcoastlines()
m.drawcounties()

# %%
pip install geopy
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install geopy
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
#Draw the locations of cities on a map of the US

import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from geopy.geocoders import Nominatim
import math

cities = [["Chicago",10],
          ["Boston",10],
          ["New York",5],
          ["San Francisco",25]]
scale = 5

map = Basemap(llcrnrlon=-119,llcrnrlat=22,urcrnrlon=-64,urcrnrlat=49,
        projection='lcc',lat_1=32,lat_2=45,lon_0=-95)

# load the shapefile, use the name 'states'
map.readshapefile('st99_d00', name='states', drawbounds=True)

# Get the location of each city and plot it
geolocator = Nominatim()
for (city,count) in cities:
    loc = geolocator.geocode(city)
    x, y = map(loc.longitude, loc.latitude)
    map.plot(x,y,marker='o',color='Red',markersize=int(math.sqrt(count))*scale)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-34-3d67d05bdb28> in <module>()
#      16
#      17 # load the shapefile, use the name 'states'
# ---> 18 map.readshapefile('st99_d00', name='states', drawbounds=True)
#      19
#      20 # Get the location of each city and plot it
#
# ~/anaconda3/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in readshapefile(self, shapefile, name, drawbounds, zorder, linewidth, color, antialiased, ax, default_encoding)
#    2132         shp.default_encoding = default_encoding
#    2133         if not os.path.exists('%s.shp'%shapefile):
# -> 2134             raise IOError('cannot locate %s.shp'%shapefile)
#    2135         if not os.path.exists('%s.shx'%shapefile):
#    2136             raise IOError('cannot locate %s.shx'%shapefile)
#
# OSError: cannot locate st99_d00.shp

# %%
m = Basemap(resolution='c', # c, l, i, h, f or None
            projection='merc',
            lat_0=54.5, lon_0=-4.36,
            llcrnrlon=-6., llcrnrlat= 49.5, urcrnrlon=2., urcrnrlat=55.2)
1
2
3
4
m = Basemap(resolution='c', # c, l, i, h, f or None
            projection='merc',
            lat_0=54.5, lon_0=-4.36,
            llcrnrlon=-6., llcrnrlat= 49.5, urcrnrlon=2., urcrnrlat=55.2)
